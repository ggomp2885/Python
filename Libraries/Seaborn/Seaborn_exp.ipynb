# %% [markdown]
# ## Seaborn Plot Mastery

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd                       # just needed for df manipulation work

# this must be set or else the plots dont work, this is the only "set_" function
# I need to use, because it holds all of the relevant functions

# ahh, so I see the reason why they have specific set_functions,
# its for when you want to keep all the other settings the same,
# but just change 1 at time ---- so I can have an initial setup command that sets the long term things, and then a small setup that I c&p into a cell for custom manipulations
# but in order to do this, this small C&P setup would have to use multiple of the smaller "set_()" functions

# also, all of these settings statements have to be run above the sns.plot() function,

# %% [markdown]
# ## Seaborn Settings & Custom functions

# %%
# Seaborn Styling settings
sns.set(context='poster',          # default     # sets font scale, lines width, and axis numbers, to a small/med/large/xlarge level, can be a little unpredictable
              font ='arial',
              font_scale=1, 
              style='darkgrid',    # default
              palette='deep',
              rc={"lines.linewidth" : 1})


# custom function to put numeric labels on the bars
# argument here looks like df['sex']
def labels_on_bars(df_column_name, ax_or_plt):
    for i in range(df_column_name.nunique()):
        ax_or_plt.text(i, 
                 df_column_name.value_counts()[i],
                 df_column_name.value_counts()[i], 
                 ha='center', va='bottom', size=16)
    return

# %% [markdown]
# ## Fonts List

# %%
import matplotlib.font_manager
matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# ['C:\\Windows\\Fonts\\BELLI.TTF',
#  'C:\\windows\\Fonts\\LSANS.TTF',
#  'C:\\windows\\Fonts\\BELLI.TTF',
#  'C:\\Windows\\Fonts\\GILI____.TTF',
#  'C:\\windows\\Fonts\\calibrii.ttf',
#  'C:\\windows\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\COLONNA.TTF',
#  'C:\\Windows\\Fonts\\POORICH.TTF',
#  'C:\\Windows\\Fonts\\DUBAI-BOLD.TTF',
#  'C:\\windows\\Fonts\\LTYPE.TTF',
#  'C:\\windows\\Fonts\\RAVIE.TTF',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'C:\\windows\\Fonts\\GOUDYSTO.TTF',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\HPSimplified_BdIt.ttf',
#  'C:\\windows\\Fonts\\DUBAI-MEDIUM.TTF',
#  'C:\\windows\\Fonts\\GILLUBCD.TTF',
#  'C:\\windows\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\LTYPE.TTF',
#  'C:\\Windows\\Fonts\\BOD_BLAR.TTF',
#  'C:\\windows\\Fonts\\GOTHICB.TTF',
#  'C:\\Windows\\Fonts\\ERASDEMI.TTF',
#  'C:\\Windows\\Fonts\\REFSAN.TTF',
#  'C:\\windows\\Fonts\\GILC____.TTF',
# ...

# %% [markdown]
# ## Colors
#
# in seaborn, the "hue" argument refers to using different colors for different categories of data, "hue"=df['column'], creates different colors for each descrete catagory in this column - this is what helps in building "double/triple plots"

# %% [markdown]
# ## Loading example dataset

# %%
#sns.get_dataset_names()    #shows example datasets available from seaborn

df = sns.load_dataset('titanic')
display(df.head(), df.shape, type(df))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# (891, 15)
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Mock Plot to show size / style changing

# %% [markdown]
# run above cell, first, to load in a dataframe

# %%
# each plot setup code
plt.figure(figsize=(3,3))        # this has to be in the same cell as the plot being made for it to work
sns.set(context='talk',          # this will stay the same as previous plot, until set() is called again
        font_scale=1.1,
        font='arial',
        palette='dark',
        rc={"lines.linewidth" : 1})


# sns.despine                   # removes the lines at the edges of the plots

ax = sns.countplot(x="sex", data=df)

plt.ylim(0, 700)                # custom y limit
labels_on_bars(df['sex'])

# %% [markdown]
# ## Plot examples
# ####  Countplots and histplots are basically the same thing
# a countplot is pre-setup to work better with discrete numbers,
#
# a histplot is pre-setup to work better with continous values

# %% [markdown]
# ## Countplot

# %%
plt.figure(figsize=(3,3))

sns.countplot(x="sex", data=df)

plt.ylim(0, 700)
labels_on_bars(df['sex'])

# the y is left out, because countplot finds the unique entries in the column
# to use as the x values, and does a count of each entry to use as their respective y values

# %% [markdown]
# ## Barplot

# %%
plt.figure(figsize=(3,3))

sns.barplot(x="sex", y="survived", hue="pclass", data=df)

# okay so with these you can summarize averages of each column with continuos y values too
# print(f' Barplot - for comparing  {sns.barplot(x="sex", y="fare", data=df)}')
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## Correlation plot

# %%
plt.figure(figsize=(8,8))
sns.set(context='notebook',
        font_scale=1.1,
        font='georgia',
        palette='dark',
        rc={"lines.linewidth" : 1})

print(f'Correlation Plot: {sns.heatmap(df.corr(), annot=True, cmap="twilight_shifted")}')
#df.corr() automatically drops any columns that arent numeric
#cmap="RdYlGn"
# Out:
# Correlation Plot: AxesSubplot(0.125,0.125;0.62x0.755)

# %% [markdown]
# ## Line Plots
# Okay so just for line plots, this is going to be easier to just do it directly through matplotlib, the seaborn implimentation requires changing the data around in a somewhat unnessary way, and using "hue"=

# %%
plt.figure(figsize=(6,4))
sns.set(context='talk',
        font_scale=1.1,
        font='georgia',
        palette='dark',
        rc={"lines.linewidth" : 1})


df = pd.DataFrame({'train_error': [100,80,50,32,22,15,10,7,5,5,5],
                   'validation_error': [100,85,60,40,30,25,22,15,14,13,12],
                   'examples' : [0,1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]})

plt.plot(df['examples'], df['train_error'], label = "train_error")
plt.plot(df['examples'], df['validation_error'], label = "validation_error")

plt.xlabel('number of examples')
plt.ylabel('error %')
plt.title('Two lines on plot with legends ')
plt.legend()
plt.ylim(0, 50)                # custom y limit
plt.show()


# print(sns.lineplot(x ='examples', y='train_error', data=df))
# Out:
#    train_error  validation_error  examples
# 0          100               100         0
# 1           80                85      1000

# %% [markdown]
# ## Multi-Plots

# %%
sns.set(context='notebook',
        font_scale=1.4,
        font='georgia',
        palette='dark',
        rc={"lines.linewidth" : 1})



fig, ax = plt.subplots(2,1, figsize=(7,15))         # figsize is now located here
#countplot
ax[0].set_title('Count of male/female')
sns.countplot(x="sex", data=df, ax=ax[0])
ax[0].set_xlabel('')

labels_on_bars(df['sex'], ax[0])

#barplot
ax[1].set_title('Survival rate, by sex and pclass')
sns.barplot(x="sex", y="survived", hue="pclass", data=df, ax=ax[1], ci=None)
ax[1].set_xlabel('')

# labels_on_bars(df['survived'], ax[1])
for p in ax[1].patches:
    ax[1].annotate(round(p.get_height(), 2),
                  (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')


plt.tight_layout(pad=4)
fig.show()
# Out:
# <ipython-input-128-427d59aeb1b7>:32: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## moving forward, it looks like Sklearn has built in implementations of learning_curve() and things like this, so Ill move my work to my sklearn doc
